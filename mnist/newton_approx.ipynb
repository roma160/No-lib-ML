# %%
import numpy as np

# %%
A = np.array([
    [1, 2],
    [3, 4]
])

# %%
def

# %%
# %run main.ipynb import *
# Out:
# c:\Program Files\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# NN model of shape (3, 2, 1)
# Layer 0: a=sigmoid(), w=(3, 2), b=(2,)
# Layer 1: a=sigmoid(), w=(2, 1), b=(1,)
#
# 8.999999912169692
# 8.582760146312836
# 4.654085835341848
# 2.6635125647274775
# 1.6566932383283137
# 1.1147694018172392
# 0.9748458905786374
# 0.9525478039782124
# 0.9493800635440041
# 0.9406607152121953

# %% [markdown]
# ## Testing training algos:

# %%
model = Model((784, 50, 10), [Functions.relu, Functions.sigmoid])
model.w *= .05
model.b *= .005

# %%
GS = 0
batch_size = 20
alpha = 0.7
for j in range(int(1e3)):
    C = 0
    G = np.array([
        np.zeros_like(model.w),
        np.zeros_like(model.b)
    ])
    for i in np.random.randint(0, len(ds_train), batch_size):
        x, y = ds_train.iloc[i]
        raw, out = forward(model, x)
        c, dw, db = backward(model, raw, out, y)
        C += c
        G[0] += dw
        G[1] += db
    if not j % int(1e2):
        print(C / batch_size)
    
    GS = GS * alpha + (1-alpha) * G**2

    model.w -= G[0] * 1e-2 / batch_size / (GS[0] + 1e-10)**.5
    model.b -= G[1] * 1e-2 / batch_size / (GS[1] + 1e-10)**.5
# Out:
# 0.05330398770224578
# 0.0361259392434659
# 0.13886147589376202
# 0.056694025359220766
# 0.18848218607176584
# 0.1643697643482149
# 0.0005386612235268353
# 0.17752439137603132
# 0.022607403893508498
# 0.054834693956075084

# %%
import matplotlib.pyplot as plt

# %%
counter = 0
c = 0
while not counter:
    x, y = ds_test.iloc[rnd.randint(0, len(ds_test)-1)]
    pred = forward(model, x)[1][-1]
    c = sum((pred - y)**2)
    counter += 1
(fig, [ax1, ax2]) = plt.subplots(1, 2, figsize=(10, 5))
ax1.imshow(x.reshape(28, -1))
ax2.plot(y)
ax2.plot(pred)
print(counter)
# Out:
# 1
